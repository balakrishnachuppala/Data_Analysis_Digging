# %%
#1. create a sample JSON object from titanic train dataset

# %%
import pandas as pd

# %%
data_titanic=pd.read_csv('https://raw.githubusercontent.com/pcsanwald/kaggle-titanic/master/train.csv')

# %%
data_titanic.head(5)
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
# Read the JSON object and convert it to pandas data frame

# %%
url = 'https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/data.json'

# %%
data_json=pd.read_json(url,orient='columns')

# %%
data_json.head(5)
# Out:
#    integer            datetime  category
# 0        5 2015-01-01 00:00:00         0
# 1        5 2015-01-01 00:00:01         0
# 2        9 2015-01-01 00:00:02         0
# 3        6 2015-01-01 00:00:03         0
# 4        6 2015-01-01 00:00:04         0

# %%
#html data reading part

# %%
import requests

# %%
url = 'https://www.worldcoinindex.com/'

# %%
crypto_url=requests.get(url)

# %%
crypto_url
# Out:
# <Response [200]>

# %%
list(crypto_url)
# Out:
# [b'\r\n<!DOCTYPE html>\r\n<html style="background-color: #FFF">\r\n<head>\r\n    \r\n\t<meta http-equiv="Content-Type" content="text/html">\r\n\t',
#  b'<meta name="mobile-web-app-capable" content="yes">\r\n    <meta charset="utf-8" />\r\n\t<meta property="og:image" content="https://ww',
#  b'w.worldcoinindex.com/content/img/worldcoinindex_social.png?v=3" />\r\n    <meta name="description" content="Cryptocoins ranked by ',
#  b'24hr trading volume, price info, charts, market cap and news" />\r\n        <meta name="keywords" content="Coin, index, worldcoin,',
#  b' coinindex, worldindex, cryptocoins, crypto, traded, exchanges, ranked, marketcap, coins, cryptocurrency ,coinprices, price, las',
#  b't trade time, trade, market cap, trading, traded, volume, rate, buy cryptocurrency, sell cryptocurrency" />\r\n    <meta name="vie',
#  b'wport" content="width=device-width, initial-scale=1, user-scalable = no">\r\n    <meta name="apple-mobile-web-app-capable" content',
# ...

# %%
crypto_url.text
# Out:
# '\r\n<!DOCTYPE html>\r\n<html style="background-color: #FFF">\r\n<head>\r\n    \r\n\t<meta http-equiv="Content-Type" content="text/html">\r\n\t<meta name="mobile-web-app-capable" content="yes">\r\n    <meta charset="utf-8" />\r\n\t<meta property="og:image" content="https://www.worldcoinindex.com/content/img/worldcoinindex_social.png?v=3" />\r\n    <meta name="description" content="Cryptocoins ranked by 24hr trading volume, price info, charts, market cap and news" />\r\n        <meta name="keywords" content="Coin, index, worldcoin, coinindex, worldindex, cryptocoins, crypto, traded, exchanges, ranked, marketcap, coins, cryptocurrency ,coinprices, price, last trade time, trade, market cap, trading, traded, volume, rate, buy cryptocurrency, sell cryptocurrency" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, user-scalable = no">\r\n    <meta name="apple-mobile-web-app-capable" content="yes" />\r\n    <meta name="propeller" content="efad6eed15cdd45139ef34d28
# ...

# %%
crypto_data = pd.read_html(crypto_url.text)

# %%
crypto_data
# Out:
# [       # Unnamed: 1           Name Ticker  Last price       %     24 high  \
#  0      1        NaN        bitcoin    BTC  $ 7,106.19  +3.49%  $ 7,170.75
#  1      2        NaN       ethereum    ETH    $ 182.55  +6.12%    $ 185.43
#  2      3        NaN       litecoin    LTC     $ 41.71  +2.50%     $ 42.26
#  3      4        NaN            eos    EOS      $ 2.63  +4.03%      $ 2.67
#  4      5        NaN    bitcoincash    BCH    $ 231.89  +5.33%    $ 236.34
#  ..   ...        ...            ...    ...         ...     ...         ...
#  97    96        NaN  bitforextoken     BF  $ 0.005543  +2.18%  $ 0.009067
#  98    97        NaN       arcblock    ABT  $ 0.089183  +2.84%  $ 0.089996
#  99    98        NaN            nem    XEM  $ 0.036526  +3.70%  $ 0.036763
#  100   99        NaN      ravencoin    RVN  $ 0.016628  +3.05%  $ 0.016918
#  101  100        NaN      uquidcoin    UQC  $ 0.543482  +5.07%  $ 0.551646
#
#           24 low Price Charts 7d 24 volume  # Coins Market cap
# ...

# %%
len(crypto_data), type(crypto_data)
# Out:
# (1, list)

# %%
crypto_data = crypto_data[0]

# %%
crypto_data
# Out:
#        # Unnamed: 1           Name Ticker  Last price       %     24 high  \
# 0      1        NaN        bitcoin    BTC  $ 7,106.19  +3.49%  $ 7,170.75
# 1      2        NaN       ethereum    ETH    $ 182.55  +6.12%    $ 185.43
# 2      3        NaN       litecoin    LTC     $ 41.71  +2.50%     $ 42.26
# 3      4        NaN            eos    EOS      $ 2.63  +4.03%      $ 2.67
# 4      5        NaN    bitcoincash    BCH    $ 231.89  +5.33%    $ 236.34
# ..   ...        ...            ...    ...         ...     ...         ...
# 97    96        NaN  bitforextoken     BF  $ 0.005543  +2.18%  $ 0.009067
# 98    97        NaN       arcblock    ABT  $ 0.089183  +2.84%  $ 0.089996
# 99    98        NaN            nem    XEM  $ 0.036526  +3.70%  $ 0.036763
# 100   99        NaN      ravencoin    RVN  $ 0.016628  +3.05%  $ 0.016918
# 101  100        NaN      uquidcoin    UQC  $ 0.543482  +5.07%  $ 0.551646
#
#          24 low Price Charts 7d 24 volume  # Coins Market cap
# ...

# %%
crypto_final = crypto_data.iloc[:,2:]

# %%
crypto_final
# Out:
#               Name Ticker  Last price       %     24 high      24 low  \
# 0          bitcoin    BTC  $ 7,106.19  +3.49%  $ 7,170.75  $ 6,844.18
# 1         ethereum    ETH    $ 182.55  +6.12%    $ 185.43    $ 170.82
# 2         litecoin    LTC     $ 41.71  +2.50%     $ 42.26     $ 40.47
# 3              eos    EOS      $ 2.63  +4.03%      $ 2.67      $ 2.52
# 4      bitcoincash    BCH    $ 231.89  +5.33%    $ 236.34    $ 218.08
# ..             ...    ...         ...     ...         ...         ...
# 97   bitforextoken     BF  $ 0.005543  +2.18%  $ 0.009067  $ 0.005407
# 98        arcblock    ABT  $ 0.089183  +2.84%  $ 0.089996  $ 0.086487
# 99             nem    XEM  $ 0.036526  +3.70%  $ 0.036763  $ 0.034457
# 100      ravencoin    RVN  $ 0.016628  +3.05%  $ 0.016918  $ 0.015948
# 101      uquidcoin    UQC  $ 0.543482  +5.07%  $ 0.551646  $ 0.517018
#
#     Price Charts 7d 24 volume  # Coins Market cap
# 0               NaN  $ 11.10B   18.33M  $ 130.32B
# ...

# %%
crypto_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             102 non-null    object
#  1   Ticker           102 non-null    object
#  2   Last price       102 non-null    object
#  3   %                102 non-null    object
#  4   24 high          102 non-null    object
#  5   24 low           102 non-null    object
#  6   Price Charts 7d  2 non-null      object
#  7   24 volume        102 non-null    object
#  8   # Coins          81 non-null     object
#  9   Market cap       81 non-null     object
# dtypes: object(10)
# memory usage: 8.1+ KB

# %%
del crypto_final['Price Charts 7d']

# %%
crypto_final = crypto_final.dropna()

# %%
crypto_final
# Out:
#             Name Ticker  Last price       %     24 high      24 low 24 volume  \
# 0        bitcoin    BTC  $ 7,106.19  +3.49%  $ 7,170.75  $ 6,844.18  $ 11.10B
# 1       ethereum    ETH    $ 182.55  +6.12%    $ 185.43    $ 170.82   $ 9.59B
# 2       litecoin    LTC     $ 41.71  +2.50%     $ 42.26     $ 40.47   $ 1.93B
# 3            eos    EOS      $ 2.63  +4.03%      $ 2.67      $ 2.52   $ 1.42B
# 4    bitcoincash    BCH    $ 231.89  +5.33%    $ 236.34    $ 218.08   $ 1.42B
# ..           ...    ...         ...     ...         ...         ...       ...
# 95          nuls   NULS  $ 0.193928  +4.03%  $ 0.196929  $ 0.185331   $ 5.97M
# 96         golem    GNT  $ 0.036881  +2.70%  $ 0.037936  $ 0.035909   $ 5.91M
# 98      arcblock    ABT  $ 0.089183  +2.84%  $ 0.089996  $ 0.086487   $ 5.67M
# 99           nem    XEM  $ 0.036526  +3.70%  $ 0.036763  $ 0.034457   $ 5.60M
# 100    ravencoin    RVN  $ 0.016628  +3.05%  $ 0.016918  $ 0.015948   $ 5.40M
#
#      # Coins Market cap
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
crypto_final['%'] = crypto_final['%'].apply(lambda x: x.strip('%'))
# Out:
# c:\users\bchuppal\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
crypto_final
# Out:
#             Name Ticker  Last price      %     24 high      24 low 24 volume  \
# 0        bitcoin    BTC  $ 7,106.19  +3.49  $ 7,170.75  $ 6,844.18  $ 11.10B
# 1       ethereum    ETH    $ 182.55  +6.12    $ 185.43    $ 170.82   $ 9.59B
# 2       litecoin    LTC     $ 41.71  +2.50     $ 42.26     $ 40.47   $ 1.93B
# 3            eos    EOS      $ 2.63  +4.03      $ 2.67      $ 2.52   $ 1.42B
# 4    bitcoincash    BCH    $ 231.89  +5.33    $ 236.34    $ 218.08   $ 1.42B
# ..           ...    ...         ...    ...         ...         ...       ...
# 95          nuls   NULS  $ 0.193928  +4.03  $ 0.196929  $ 0.185331   $ 5.97M
# 96         golem    GNT  $ 0.036881  +2.70  $ 0.037936  $ 0.035909   $ 5.91M
# 98      arcblock    ABT  $ 0.089183  +2.84  $ 0.089996  $ 0.086487   $ 5.67M
# 99           nem    XEM  $ 0.036526  +3.70  $ 0.036763  $ 0.034457   $ 5.60M
# 100    ravencoin    RVN  $ 0.016628  +3.05  $ 0.016918  $ 0.015948   $ 5.40M
#
#      # Coins Market cap
# ...
